# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
file_location = "C:/Users/kramer-cr/Documents/MAS 2.0/Programming/Ground-Station/COSMOS/COSMOS-Data/log/IMU_output_06-09-2021-13.50.csv"
df = pd.read_csv(file_location)
df_ypr = df.iloc[:,0:3]

# %%
df_accel = df.iloc[:,3:6]

# %%
df_rate = df.iloc[:, 6:9]

# %%
TOF = 30

# %%
df_ypr.plot()
plt.xlim([0, TOF+1])
df_accel.plot()
plt.xlim([0, TOF+1])
df_rate.plot()
plt.xlim([0, TOF+1])
# Out:
# (0.0, 31.0)
